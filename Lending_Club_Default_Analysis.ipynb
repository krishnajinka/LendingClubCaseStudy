# %%
# Lending club case study

print("Lending club case study")
# Out:
# Lending club case study

# %%
#import libraries
import pandas as pd  #Data Manuplation
import seaborn as sns # Data Visualization
import matplotlib.pyplot as plt #Data Visualization

# display all columns
pd.set_option("display.max_columns",None)
#pd.set_option("display.max_rows",None)

#import dataset
loan = pd.read_csv("loan.csv")
print("loans")
#print(loan.head(10))
print(loan.columns)
loan.info()
# Out:
# loans
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB
# C:\Users\krishnakumar\AppData\Local\Temp\ipykernel_19872\3679470167.py:11: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv("loan.csv")

# %%
# Gathering information -columns
round((loan.isnull().sum()/loan.shape[0])*100,2)
# Out:
# id                              0.0
# member_id                       0.0
# loan_amnt                       0.0
# funded_amnt                     0.0
# funded_amnt_inv                 0.0
#                               ...
# tax_liens                       0.1
# tot_hi_cred_lim               100.0
# total_bal_ex_mort             100.0
# total_bc_limit                100.0
# total_il_high_credit_limit    100.0
# Length: 111, dtype: float64

# %%
## Section 2:  Cleancing the Data
###Any duplicate Loan ID in the system required to delete
is_loanidduplicate=loan['id'].duplicated().any()
print(f'Duplicated Loan id  is {is_loanidduplicate}')
# Out:
# Duplicated Loan id  is False

# %%
### section3: Null Check for the row
row_nullinfo=loan.isnull().all(axis=1).sum()

print(f'Null rows in Loan data {row_nullinfo}')
col_nullinfo=loan.isnull().all(axis=0).sum()
print(f'Null column in Loan data {col_nullinfo}')
# Out:
# Null rows in Loan data 0
# Null column in Loan data 54

# %%
### find the null columns in the data 
are_null_or_zero = loan.isnull().sum() | (loan == 0).sum()
print(f'empty column details {are_null_or_zero}')
# Out:
# empty column details id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                 129
#                               ...
# tax_liens                     39679
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
### Droping all the  empty Columns
columns_to_drop = ['tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort','total_il_high_credit_limit']
loan = loan.drop(columns=columns_to_drop)

# %%
### Droping 
#According to our analysis below are the more relevent fields in this analysis as per Data dictionary.
#loan_amnt,funded_amnt,int_rate,Term ,emp_length,home_ownership,annual_inc,loan_status,Purpose,DTI,inq_last_6mths,Open_account ,Revol_bal,
#revol_util,total_acc,out_prncp_inv,total_pymnt_inv,total_rec_int,total_rec_late_fee,recoveries,collection_recovery_fee
#So droping columng having less populated data and irrevelent columns
columns_to_drop = ['total_cu_tl',  'member_id','url','zip_code','verification_status',
                 'mths_since_last_major_derog','inq_fi']
loan = loan.drop(columns=columns_to_drop)

# %%
# missing value -rows
round((loan.isnull().sum(axis=1)/loan.shape[0])*100,2)
# Out:
# 0        0.13
# 1        0.13
# 2        0.13
# 3        0.13
# 4        0.12
#          ...
# 39712    0.13
# 39713    0.13
# 39714    0.14
# 39715    0.14
# 39716    0.13
# Length: 39717, dtype: float64

# %%
#statistics represtation of Data
loan.describe()
# Out:
#                  id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  3.971700e+04  39717.000000  39717.000000     39717.000000
# mean   6.831319e+05  11219.443815  10947.713196     10397.448868
# std    2.106941e+05   7456.670694   7187.238670      7128.450439
# min    5.473400e+04    500.000000    500.000000         0.000000
# 25%    5.162210e+05   5500.000000   5400.000000      5000.000000
# 50%    6.656650e+05  10000.000000   9600.000000      8975.000000
# 75%    8.377550e+05  15000.000000  15000.000000     14400.000000
# max    1.077501e+06  35000.000000  35000.000000     35000.000000
#
#         installment    annual_inc           dti   delinq_2yrs  inq_last_6mths  \
# count  39717.000000  3.971700e+04  39717.000000  39717.000000    39717.000000
# mean     324.561922  6.896893e+04     13.315130      0.146512        0.869200
# std      208.874874  6.379377e+04      6.678594      0.491812        1.070219
# ...

# %%
# Get the rows, Look at the rows 100 to 200 and 3 columns of loan amount, term of loan and interest rate. 
loan.loc[100:200,['loan_amnt','term','int_rate']]
# Out:
#      loan_amnt        term int_rate
# 100       6200   36 months    9.91%
# 101      16000   60 months   17.58%
# 102       6000   36 months    8.90%
# 103       7200   36 months    9.91%
# 104       9500   36 months    8.90%
# ..         ...         ...      ...
# 196      25000   36 months   11.71%
# 197       9000   36 months   12.69%
# 198      13250   36 months   10.65%
# 199      20000   36 months   13.49%
# 200       3000   36 months   14.65%
#
# [101 rows x 3 columns]

# %%
# See the first 5 columns of rows 100 to 200  
loan.iloc[100:200,0:5]
# Out:
#           id  loan_amnt  funded_amnt  funded_amnt_inv        term
# 100  1068509       6200         6200           6200.0   36 months
# 101  1034693      16000        16000          16000.0   60 months
# 102  1068508       6000         6000           6000.0   36 months
# 103  1066641       7200         7200           7200.0   36 months
# 104  1068315       9500         9500           9500.0   36 months
# ..       ...        ...          ...              ...         ...
# 195  1067038      12000        12000          12000.0   36 months
# 196  1067030      25000        25000          25000.0   36 months
# 197  1065350       9000         9000           9000.0   36 months
# 198  1067028      13250        13250          13250.0   36 months
# 199  1061877      20000        20000          20000.0   36 months
#
# [100 rows x 5 columns]

# %%
# see specific columns for rows 100 to 200
loan.iloc[100:200,[0,2,3]]
# Out:
#           id  funded_amnt  funded_amnt_inv
# 100  1068509         6200           6200.0
# 101  1034693        16000          16000.0
# 102  1068508         6000           6000.0
# 103  1066641         7200           7200.0
# 104  1068315         9500           9500.0
# ..       ...          ...              ...
# 195  1067038        12000          12000.0
# 196  1067030        25000          25000.0
# 197  1065350         9000           9000.0
# 198  1067028        13250          13250.0
# 199  1061877        20000          20000.0
#
# [100 rows x 3 columns]

# %%
# count number of loans of a perticular term. This shows that there are 29096 loans of term 36 months and 10621 loans of 
# 60 months term 
loan['term'].value_counts()
# Out:
# term
#  36 months    29096
#  60 months    10621
# Name: count, dtype: int64

# %%
# Get the smallest 5 loans 
loan.nsmallest(5, 'loan_amnt')
# Out:
#            id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 38863  312505        500          500            450.0   36 months    9.76%
# 39275  242695        500          500            500.0   36 months   10.71%
# 39373  216698        500          500            500.0   36 months   10.46%
# 39397  211133        500          500            475.0   36 months   11.41%
# 39544  164346        500          500            400.0   36 months    8.07%
#
#        installment grade sub_grade  \
# 38863        16.08     B        B2
# 39275        16.31     B        B5
# 39373        16.25     B        B5
# 39397        16.47     C        C3
# 39544        15.69     A        A4
#
#                                                emp_title emp_length  \
# 38863                         Hughes, Hubbard & Reed LLP    7 years
# 39275                                                NaN   < 1 year
# 39373                         THe University of Illinois    3 years
# ...

# %%
# Get the largest 5 loan amounts 
loan.nlargest(5, 'loan_amnt')
# Out:
#           id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 80   1068994      35000        22075          22050.0   60 months   17.27%
# 128  1068159      35000        35000          35000.0   36 months    8.90%
# 185  1067084      35000        35000          35000.0   36 months   10.65%
# 268  1066155      35000        26825          26800.0   60 months   18.64%
# 276  1065896      35000        35000          35000.0   36 months    8.90%
#
#      installment grade sub_grade                   emp_title emp_length  \
# 80        551.84     D        D3   tutor Per ini Corporation    3 years
# 128      1111.37     A        A5         City of Los Angeles    6 years
# 185      1140.07     B        B2  baylor college of medicine    2 years
# 268       690.56     E        E1              Navistar, Inc.    8 years
# 276      1111.37     A        A5                  Twitch LLC    5 years
#
#     home_ownership  annual_inc issue_d loan_status pymnt_plan  \
# ...

# %%
#Data Cleaning
print("Data cleaning")
# loan.columns
# "member_id" already removed earlier
unnecessary_columns = ["id"]
loan.drop(unnecessary_columns,axis=1,inplace=True)
loan.columns
# Out:
# Data cleaning
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'issue_d', 'loan_status', 'pymnt_plan',
#        'desc', 'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt',
# ...

# %%
# Data cleaning
# round((loan.isnull().sum()/loan.shape[0])*100,2)
# emp_length: Employment length in years. Possible values are between 0 and 10 
#   where 0 means less than one year and 10 means ten or more years. 
print("remove null and NA values")
loan.dropna(subset = ['emp_length'], inplace=True)
round((loan.isnull().sum()/loan.shape[0])*100,2)
# Out:
# remove null and NA values
# loan_amnt                 0.0
# funded_amnt               0.0
# funded_amnt_inv           0.0
# term                      0.0
# int_rate                  0.0
#                         ...
# num_tl_op_past_12m      100.0
# pct_tl_nvr_dlq          100.0
# percent_bc_gt_75        100.0
# pub_rec_bankruptcies      1.8
# total_bc_limit          100.0
# Length: 99, dtype: float64

# %%
# Data Cleaning
# Interest rate column has % symbol, need to remove it, so that we can make a graph out of the numerical value
loan["int_rate"] = loan['int_rate'].apply(lambda x: float(x.split("%")[0]))
loan["int_rate"]
# Out:
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 4        12.69
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: int_rate, Length: 38642, dtype: float64

# %%
loan['emp_length']
# Out:
# 0        10+ years
# 1         < 1 year
# 2        10+ years
# 3        10+ years
# 4           1 year
#            ...
# 39712      4 years
# 39713      3 years
# 39714     < 1 year
# 39715     < 1 year
# 39716     < 1 year
# Name: emp_length, Length: 38642, dtype: object

# %%
# There is a need to remove non numeric characters from the emp_length, so that we can use this column for analysis
# For example years, < symbol, and also n/a. 
# Verify the csv file by saving as xls and do a pivot table to keep validating the data parallely and confirming. 

loan['emp_length'] = loan['emp_length'].astype("str")
loan['emp_length'] = loan['emp_length'].apply(lambda x: x.replace("years",""))
loan['emp_length'] = loan['emp_length'].apply(lambda x: x.replace("year",""))
loan['emp_length'] = loan['emp_length'].apply(lambda x: x.replace("10+","11"))
loan['emp_length'] = loan['emp_length'].apply(lambda x: x.replace("< 1","0"))

# %%
# Verify the employment length column
loan['emp_length'].value_counts()
# output confirms that, the employment length column is cleaned up.
# Out:
# emp_length
# 11     8879
# 0      4583
# 2      4388
# 3      4095
# 4      3436
# 5      3282
# 1      3240
# 6      2229
# 7      1773
# 8      1479
# 9      1258
# Name: count, dtype: int64

# %%
# Below is option code to covert the type of employment length to integer. Needed for analysis
loan['emp_length']=loan['emp_length'].astype('int')
loan['emp_length'].value_counts()
# Out:
# emp_length
# 11    8879
# 0     4583
# 2     4388
# 3     4095
# 4     3436
# 5     3282
# 1     3240
# 6     2229
# 7     1773
# 8     1479
# 9     1258
# Name: count, dtype: int64

# %%
# Graph1 : What are the impacts of employment lenght on the loan defaults, amount of loan etc : TODO

loan.groupby(['emp_length','int_rate']).size().reset_index(name='Count').sort_values('Count',ascending=False)
# Out:
#       emp_length  int_rate  Count
# 2723          11     10.99    233
# 2789          11     13.49    220
# 2736          11     11.49    202
# 2640          11      5.42    185
# 2661          11      7.51    182
# ...          ...       ...    ...
# 471            1     14.07      1
# 2485           9     10.83      1
# 1727           6      7.91      1
# 1724           6      7.75      1
# 548            1     17.80      1
#
# [2956 rows x 3 columns]

# %%
# POINT 2 , look at annual income 
loan["annual_inc"].describe()
# Out:
# count    3.864200e+04
# mean     6.960828e+04
# std      6.425320e+04
# min      4.000000e+03
# 25%      4.140000e+04
# 50%      6.000000e+04
# 75%      8.319999e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %%
loan["annual_inc"]
# Out:
# 0         24000.0
# 1         30000.0
# 2         12252.0
# 3         49200.0
# 4         80000.0
#            ...
# 39712    110000.0
# 39713     18000.0
# 39714    100000.0
# 39715    200000.0
# 39716     22000.0
# Name: annual_inc, Length: 38642, dtype: float64

# %%
# Covert the annual income to categorical values 

#low-income: 0-50000
#mid-income: 50001-100000
#high-income: 100001>
def annul_inc_conversion(x):
  if x<= 50000:
    return "low income"
  elif x> 50000 and x <= 100000:
    return "medium income"
  else:
    return "high income"

# %%
loan["annual_inc_group"] = loan["annual_inc"].apply(lambda x:annul_inc_conversion(x))

# %%
loan["annual_inc_group"]
# Out:
# 0           low income
# 1           low income
# 2           low income
# 3           low income
# 4        medium income
#              ...
# 39712      high income
# 39713       low income
# 39714    medium income
# 39715      high income
# 39716       low income
# Name: annual_inc_group, Length: 38642, dtype: object

# %%
# Convert interest rate column to categorical values
#low-intersrt: 7.5
#mid-interst: 7.6-13
#high-insterst: 13+
def interst_rate_conversion(x):
  if x<= 7.5:
    return "low interst rate"
  elif x>7.5  and x <= 13.0:
    return "medium interst rate"
  else:
    return "high interst rate"

# %%
loan["int_rate_group"]= loan["int_rate"].apply(lambda x:interst_rate_conversion(x) )

# %%
loan["int_rate_group"]
# Out:
# 0        medium interst rate
# 1          high interst rate
# 2          high interst rate
# 3          high interst rate
# 4        medium interst rate
#                 ...
# 39712    medium interst rate
# 39713    medium interst rate
# 39714    medium interst rate
# 39715       low interst rate
# 39716      high interst rate
# Name: int_rate_group, Length: 38642, dtype: object

# %%
#Data Analysis

loan['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     32145
# Charged Off     5399
# Current         1098
# Name: count, dtype: int64

# %%
# out of the loan data, see only the loan which are current and we need to analysis on these loans to 
# bring out the facts about which of these loans might be defaulted
# store the current loan status as a new variable named loan final 
loan_final = loan[~(loan["loan_status"] == "Current")]

# %%
loan_final.head()
loan_final['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     32145
# Charged Off     5399
# Name: count, dtype: int64

# %%
loan_final.describe()
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count  37544.000000  37544.000000     37544.000000  37544.000000
# mean   11119.329986  10853.560489     10280.495739     11.963319
# std     7354.098954   7096.316776      7034.124211      3.683012
# min      500.000000    500.000000         0.000000      5.420000
# 25%     5500.000000   5400.000000      5000.000000      8.940000
# 50%    10000.000000   9600.000000      8850.000000     11.830000
# 75%    15000.000000  15000.000000     14075.000000     14.420000
# max    35000.000000  35000.000000     35000.000000     24.400000
#
#         installment    emp_length    annual_inc           dti   delinq_2yrs  \
# count  37544.000000  37544.000000  3.754400e+04  37544.000000  37544.000000
# mean     324.650164      5.167057  6.940708e+04     13.284186      0.147107
# std      208.901055      3.887849  6.467698e+04      6.660551      0.493479
# ...

# %%
# let us look at the loans which are not currently running 
# this will get loan which is fully paid or charged off (defaulted)
loan_final = loan[~(loan["loan_status"] == "Current")]
loan_final.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       5000         5000           4975.0   36 months     10.65       162.87
# 1       2500         2500           2500.0   60 months     15.27        59.83
# 2       2400         2400           2400.0   36 months     15.96        84.33
# 3      10000        10000          10000.0   36 months     13.49       339.31
# 5       5000         5000           5000.0   36 months      7.90       156.46
#
#   grade sub_grade             emp_title  emp_length home_ownership  \
# 0     B        B2                   NaN          11           RENT
# 1     C        C4                 Ryder           0           RENT
# 2     C        C5                   NaN          11           RENT
# 3     C        C1   AIR RESOURCES BOARD          11           RENT
# 5     A        A4  Veolia Transportaton           3           RENT
#
#    annual_inc issue_d  loan_status pymnt_plan  \
# ...

# %%
# Univariate analysis

# Look at how many loans were fully paid and charged off
# Look at loan status and find out how many of each category are there. 
def count_analysis(x,):
  print(loan_final[str(x)].value_counts())
count_analysis('loan_status')
# Out:
# loan_status
# Fully Paid     32145
# Charged Off     5399
# Name: count, dtype: int64

# %%
# Univariate analysis 
# Look at the interest rate and count the number of categories
count_analysis('int_rate_group')
# Out:
# int_rate_group
# medium interst rate    18147
# high interst rate      14287
# low interst rate        5110
# Name: count, dtype: int64

# %%
# Univariate analysis
# For what purpose the loans were taken. What are the different purpose and their count 
count_analysis('purpose')

# Analysis: from the below results, we can see highest loans were taken for paying other loans
# Out:
# purpose
# debt_consolidation    17675
# credit_card            4899
# other                  3713
# home_improvement       2785
# major_purchase         2080
# small_business         1710
# car                    1448
# wedding                 913
# medical                 656
# moving                  552
# house                   354
# vacation                348
# educational             317
# renewable_energy         94
# Name: count, dtype: int64

# %%
# Univariate analysis 
# What is the max, min, average loan amount taken 
max_loan = loan_final['loan_amnt'].max()
print(f'Max loan amount taken is {max_loan}')

min_loan = loan_final['loan_amnt'].min()
print(f'Min loan amount taken is {min_loan}')

avg_loan = round(loan_final['loan_amnt'].mean(), 2)
print(f'Avg loan amount taken is {avg_loan}')
# Out:
# Max loan amount taken is 35000
# Min loan amount taken is 500
# Avg loan amount taken is 11119.33

# %%
#Bi-Variate Analysis

# How many loans which were defaulted, had high interest rate and their count. Similarly look at low and med int rate
# High int rate loans have the risk of getting defaulted, hence will require more scrutiny before giving loan 

loan_final.groupby(['loan_status','int_rate_group']).size().reset_index(name='Count')
# Out:
#    loan_status       int_rate_group  Count
# 0  Charged Off    high interst rate   3110
# 1  Charged Off     low interst rate    231
# 2  Charged Off  medium interst rate   2058
# 3   Fully Paid    high interst rate  11177
# 4   Fully Paid     low interst rate   4879
# 5   Fully Paid  medium interst rate  16089

# %%
# Bi-Variate analysis
#Recommendation: applicant who are ready to take loan at high interst rate, do more investigation about applicant

loan_final.groupby(['loan_status','annual_inc_group']).size().reset_index(name='Count')

# Analysis: low income category applicants have defaulted more. Hence more scrutiny, background check is needed
# Out:
#    loan_status annual_inc_group  Count
# 0  Charged Off      high income    589
# 1  Charged Off       low income   2438
# 2  Charged Off    medium income   2372
# 3   Fully Paid      high income   4844
# 4   Fully Paid       low income  12240
# 5   Fully Paid    medium income  15061

# %%
# Bi-variate analysis

# What is the purpose of loan taken and out of them, which ones were defaulted and which ones fully paid and how many are there

loan_final.groupby(['loan_status','purpose']).size().reset_index(name='Count').sort_values('Count',ascending=False).head(30)

# Analysis : Defaulted loans most of them from debt consolidation. It shows, that more scrutiny is needed when giving loans
# for debt consolidation
# to see further, we can include 3rd column and see which income group high/med/low defaulted under what purpose
# loan_final.groupby(['loan_status','annual_inc_group','purpose']).size().reset_index(name='Count').sort_values('Count',ascending=False).head(30)
# Out:
#     loan_status             purpose  Count
# 16   Fully Paid  debt_consolidation  14996
# 15   Fully Paid         credit_card   4389
# 23   Fully Paid               other   3117
# 2   Charged Off  debt_consolidation   2679
# 18   Fully Paid    home_improvement   2455
# 20   Fully Paid      major_purchase   1869
# 14   Fully Paid                 car   1293
# 25   Fully Paid      small_business   1248
# 27   Fully Paid             wedding    821
# 9   Charged Off               other    596
# 21   Fully Paid             medical    555
# 1   Charged Off         credit_card    510
# 22   Fully Paid              moving    468
# 11  Charged Off      small_business    462
# 4   Charged Off    home_improvement    330
# 26   Fully Paid            vacation    298
# 19   Fully Paid               house    295
# 17   Fully Paid         educational    265
# 6   Charged Off      major_purchase    211
# 0   Charged Off                 car    155
# 7   Charged Off             medical    101
# ...

# %%
# Bi-variate analysis , here added one more column
loan_final.groupby(['loan_status','annual_inc_group','int_rate']).size()
# Out:
# loan_status  annual_inc_group  int_rate
# Charged Off  high income       5.99        1
#                                6.17        1
#                                6.54        3
#                                6.99        1
#                                7.14        2
#                                           ..
# Fully Paid   medium income     23.13       2
#                                23.22       3
#                                23.52       1
#                                23.59       1
#                                23.91       3
# Length: 1728, dtype: int64

# %%
#Data Visaulaization
loan_final
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0           5000         5000           4975.0   36 months     10.65
# 1           2500         2500           2500.0   60 months     15.27
# 2           2400         2400           2400.0   36 months     15.96
# 3          10000        10000          10000.0   36 months     13.49
# 5           5000         5000           5000.0   36 months      7.90
# ...          ...          ...              ...         ...       ...
# 39712       2500         2500           1075.0   36 months      8.07
# 39713       8500         8500            875.0   36 months     10.28
# 39714       5000         5000           1325.0   36 months      8.07
# 39715       5000         5000            650.0   36 months      7.43
# 39716       7500         7500            800.0   36 months     13.75
#
#        installment grade sub_grade                   emp_title  emp_length  \
# ...

# %%
#univariate:
#continuous
sns.displot(loan_final['loan_amnt'])
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(loan_final['installment'])
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(y=loan_final['installment'])
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: ylabel='installment'>

# %%
sns.boxplot(y=loan_final['loan_amnt'])
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: ylabel='loan_amnt'>

# %%
sns.histplot(loan_final['loan_amnt'])
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='loan_amnt', ylabel='Count'>

# %%
# Draw a graph for uni variate analysis
# Use the cleansed data for analysis

def univariate_categorical_analysis(column):
  sns.countplot(x=loan_final[str(column)])

# %%
# while analyzing the data in a column, asking question, what % of loans are charged off vs fully paid
univariate_categorical_analysis("loan_status")
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Analysis: what is the total term of loans. Graph shows, 36 months term more loans than 60 months
univariate_categorical_analysis("term")
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Analysis: Medium int rates are highest
univariate_categorical_analysis("int_rate_group")
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
loan_final.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        ...
#        'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m',
#        'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75',
#        'pub_rec_bankruptcies', 'total_bc_limit', 'annual_inc_group',
#        'int_rate_group'],
#       dtype='object', length=101)

# %%
# Analysis: Look at the verification status column and see which category are highest
# univariate_categorical_analysis("verification_status_joint")

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
univariate_categorical_analysis("purpose")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
#Bivariate analysis , when both columns are continuous
#Here, loan amount and installment are continuous
# Shows both increasing together, well corelated
sns.scatterplot(data=loan_final,x="loan_amnt",y="installment")
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='loan_amnt', ylabel='installment'>

# %%
# Analysis when both columns are categorical in nature
# Look at loan status and term
sns.countplot(data=loan_final,x="loan_status",hue="term")
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Bivariate analysis wth graph. look at loan status and interest rate togethe
# More number of med interest rates are fully paid 
# whereas high interest rate loans were more defaulted
sns.countplot(data=loan_final,x="loan_status",hue="int_rate_group")
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
loan_final.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        ...
#        'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m',
#        'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75',
#        'pub_rec_bankruptcies', 'total_bc_limit', 'annual_inc_group',
#        'int_rate_group'],
#       dtype='object', length=101)

# %%
# Bivariate analysis with graphs
# Both low and med income group applicants have defaulted more. Hence background check is needed more. 

sns.countplot(data=loan_final,x="loan_status",hue="annual_inc_group")
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# The purpose of using a heatmap to visualize the correlation matrix of a dataset, 
# like the loan_final.corr() in this case, is for multi-variate analysis, specifically to:
# Identify Relationships: It helps in identifying the relationships between multiple variables at once. 
# The correlation values range from -1 to 1, where:

# 1 indicates a perfect positive linear relationship,
# -1 indicates a perfect negative linear relationship, and
# 0 indicates no linear relationship between two variables.
# Multi-variate analysis
import numpy as np
loan_final['term_numeric'] = loan_final['term'].str.extract('(\d+)').astype(float)
numeric_cols = loan_final.select_dtypes(include=[np.number])  # Select only numeric columns
# Out:
# C:\Users\krishnakumar\AppData\Local\Temp\ipykernel_19872\3586058103.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_final['term_numeric'] = loan_final['term'].str.extract('(\d+)').astype(float)

# %%
selected_columns = ['funded_amnt_inv', 'installment', 'annual_inc', 'term_numeric','loan_amnt', 'int_rate', 'delinq_2yrs', 'mths_since_last_record', 'revol_bal', 'total_rec_late_fee', 'total_pymnt']

selected_data = loan_final[selected_columns]

# Calculate the correlation matrix for the selected columns
corr_matrix = selected_data.corr()

sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(data=loan_final,y="loan_amnt",x='term',hue='loan_status')
# Out:
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\krishnakumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
